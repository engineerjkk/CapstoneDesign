# %% [markdown]
# * 이진 탐색(binary Search)
# - 이진 탐색은 테이블의 중앙에 있는 값을 조사하여 찾는 항목이 왼쪽에 있는지 오른쪽에 있는지를 판단한다. 찾는 항목이 왼쪽에 있다면 이제 오른쪽은 탐색할 필요가 없어지고, 따라서 매 단계마다 검색해야 할 항목수가 반으로 줄어든다.

# %% [markdown]
# 7.11 이진 탐색 알고리즘의 특징이 아닌 것은? 3
# 1. 탐색 효율이 좋고 탐색 시간이 적게 소요된다. O
# 2. 검색할 데이터가 정렬되어 있어야 한다. O
# 3. 파보나치 수열에 따라 다음에 비교할 대상을 선정하여 검색한다. X
# 4. 비교를 할 때마다 검색 대상이 되는 데이터의 수가 절반으로 줄어든다. O

# %% [markdown]
# - 순차 탐색
# - 순차 탐색은 정렬되지 않은 테이블에서도 원하는 레코드를 찾을 수 있는 가장 단순하고 직관적인 방법으로, 테이블의 각 레코드를 처음부터 하나씩 순서대로 검사하여 원하는 레코드를 찾는다. 탐색을 위한 레코드들이 리스트에 저장되어 있다고 하자. 탐색 함수는 탐색 대상인 리스트 A와 탐색 키 key, 그리고 리스트에서의 탐색 범위 low, high를 매개변수로 전달받는다.
# - 결국 순차 탐색의 시간 복잡도는 O(n)이다. 이 방법은 간단하고 구현하기 쉽지만 효율적이지는 않다. 그러나 테이블이 정렬되어 있지 않다면 순차 탐색 이외에 별다른 대안은 없다.

# %% [markdown]
# - 보간 탐색
# - 보간 탐색은 이진탐색의 일종으로 우리가 사전에서 단어를 찾을 때와 같이 탐색키가 존재할 위치를 예측하여 탐색하는 방법이다. 예를 들어 ㅎ으로 시작하는 단어는 사전의 뒷부분에서 찾고 ㄱ으로 시작하는 단어는 앞부분에서 찾는 것과 같은 원리이다.

# %% [markdown]
# 7.12 키 값 28을 가지고 아래의 리스트를 탐색할 때 다음의 탐색 방법에 따른 탐색 과정을 그리고 탐색 시에 필요한 비교 연산 횟수를 구하여라
#  8|11|12|15|16|19|20|23|25|28|29|31|33|35|38|40
#  1. 순차탐색 : 10
#  2. 이진탐색 : 3
#  3. 보간탐색 : 3

# %% [markdown]
# # 12장

# %% [markdown]
# - 선택 정렬 : 입력의 크기에 따라 자료 이동 횟수가 결정된다.
# - 삽입 정렬 : 레코드의 많은 이동이 필요하지만 대부분의 레코드가 이미 정렬되어 있는 경우에는 효율적이다.
# - 버블 정렬 : 인접 요소를 교환하는 방식의 가장 간단한 알고리즘을 사용한다.
#
# 만약 정렬해야 할 데이터가 많고 자주 정렬해야 한다면 보다 효율적인 방법이 필요하다. 이러한 정렬 알고리즘은 컴퓨터 분야에서 가장 많이 연구된 분야중의 하나로 지금까지 매우 다양한 정렬 방법들이 제안되었다. 몇 가지 효율적인 정렬 방법들을 살펴보자.
# 1. 셀 정렬 : 삽입 정렬 개념을 개선한 방법
# 2. 힙 정렬 : 추가적인 메모리 공간이 필요 없는 제자리 정렬로 구현하는 방법
# 3. 병합 정렬 : 연속적인 분할과 병합을 이용하는 방법
# 4. 퀵 정렬, 이중피벗 큇 정렬 : 피벗을 이용한 정렬 방법으로 대표적인 효율적인 정렬 알고리즘
# 5. 기수 정렬, 카운팅 정렬 : 항목의 비교를 사용하지 않고 분배를 이용해 정렬하는 방법이지만 적용할 수 있는 킷값에 제한이 있는 알고리즘

# %% [markdown]
# 12.1 입력 데이터의 구성과 상관없이 자료의 이동횟수가 결정되는 정렬 알고리즘을 모두 골라라.
# - 선택정렬, 힙정렬, 병합정렬, 기수정렬, 카운팅정렬

# %% [markdown]
# 12.2 거의 정렬이 되어 있는 데이터에 대해 좋은 성능을 보이는 정렬 알고리즘을 모두 골라라
# - 삽입 정렬, 버블 정렬, 셸 정렬, 퀵정렬, 이중피벗 퀵정렬, 팀정렬

# %% [markdown]
# 12.3 연속적인 분할과 병합을 이용하는 효율적인 알고리즘이지만 임시 배열이 필요한 정렬 알고리즘을 골라라
# - 병합 정렬

# %% [markdown]
# 12.4 피벗을 이용하는 대표적인 효율적인 정렬 알고리즘들을 골라라.
# - 퀵 정렬, 이중피벗 퀵 정렬

# %% [markdown]
# 12.5 항목의 비교를 사용하지 않고 분배를 이용해 정렬하는 방법들을 골라라
# - 기수 정렬, 카운팅 정렬

# %% [markdown]
# 12.6 최악의 경우에도 시간 복잡도가 O(nlog2n)인 정렬 방법을 모두 골라라
# - 힙정렬, 큌정렬, 팀정렬

# %% [markdown]
# 12.7 평균적인 시간 복잡도가 O(n^2)인 정렬 알고리즘을 모두 골라라.
# - 선택정렬, 삽입정렬,버블정렬

# %% [markdown]
# 12.8 최악의 경우 시간 복잡도가 명확히 O(n^2)인 정렬 알고리즘을 모두 골라라
# - 선택정렬, 삽입정렬, 버블정렬, 셸정렬, 퀵정렬, 이중피벗 퀵 정렬

# %% [markdown]
# 12.9 O(nlog2n)이라는 정렬의 이론적인 하한선을 깰 수 있는 정렬 방법들을 모두 골라라
# - 기수정렬

# %% [markdown]
# 12.10 삽입정렬과 관련이 있는 정렬 방법들을 모두 골라라.
# - 셸 정렬

# %% [markdown]
# 12.11 다음 중 정렬 대상이 아스키 문자들인 경우 이들을 정렬하기 위한 가장 효율적인 정렬 방법은? 4
# 1. 퀵 정렬 2. 힙 정렬 3. 병합 정렬 4. 카운팅 정렬
#
# - 카운팅 정렬은 입력 데이터가 크지 않은 일정한 범위의 값을 가진 양수라면 매우 효율적이다. 예를 들어, 아스키 문자열의 모든 문자들을 정렬하는데 사용할 수 있는데, 아스키 문자들은 모두 0~255 이내의 값을 갖기 때문이다.

# %% [markdown]
# 12.12 비교를 이용한 정렬 알고리즘에 대한 다음 설명 중에서 틀린 것은? 4
# 1. 난수배열에 대해 비교기반 정렬은 최소 O(nlog2n)의 시간이 걸린다. O
# 2. 어떤 비교기반 정렬 알고리즘도 비교할 때 위치를 사용하면 안정적이므로 만들 수 있다.
# 3. 카운팅 정렬은 비교기반 정렬이 아니다. O
# 4. 병합 정렬은 비교기반 정렬이 아니다.  X

# %% [markdown]
# 12.13 다음의 입력 배열을 셸 정렬 이용하여 오름차순으로 정렬하려고 한다. 각 단계에서의 간격(gap)과 배열의 내용을 적어라. 단, 간격은 배열 크기의 절반으로 시작한다. 또한 간격이 짝수이면 1을 더해 홀수로 만들어 사용하라.
# 7|4|9|6|3|8|7|5
# 1. 7|4|5|6|3|8|7|9 -> 간격이 5인 부분리스트
# 2. 6|3|5|7|4|8|7|9 -> 간격이 3인 부분리스트
# 3. 3|5|6|4|7|7|8|9 -> 간격이 1인 부분리스트
#
# - 삽입 정렬
# 4. 3|4|5|6|7|7|8|9

# %% [markdown]
# 12.14 셸 정렬의 삽입 정렬의 어떤 특성을 이용하는가? 삽입 정렬이 효율적인 경우와 비효율적인 경우의 입력에 대한 예를 들고 설명하라.
# - 삽입 정렬이 어느 정도 정렬된 배열에 대해서는 대단히 빠른 것에 착안했다.
# 따라서 오름차순으로 정렬할 경우
# - 1,2,3,4,5,7,6,8,9 와같은 조금만 정렬이 필요할 때 효율적이며
# - 9,8,7,6,5,4,3,2,1 과같은 정렬이 많이 필요할 때에는 비효율적이다.

# %% [markdown]
# ~12.15 다음의 정수 배열을 힙 정렬을 사용하여 오름차순으로 정렬하려고 한다. 단, 힙 정렬은 추가적인 배열을 사용하지 않는 제자리 정렬로 구현한다.~
# - 71|49|92|55|38|82|72|53
# 최대 힙이 만들어지는 과정을 트리를 이용해 나타내라. 또한 최대 힙에서의 배열의 내용을 적어라

# %% [markdown]
# ~12.16 위 문제에서 최대 힙에서 배열을 정렬하는 과정을 트리를 이용해 나타내고, 최종 배열의 내용을 적어라~

# %% [markdown]
# 12.17 다음의 정수 배열을 병합 정렬을 사용하여 오름차순으로 정렬하려고 한다. 각 단계에서의 배열의 내용을 나타내어라.
# - 71|49|92|55|38|82|72|53

# %% [markdown]
# 1. [71,49,92,55],[38,82,72,53]
# 2. [71,49],[92,55],[38,82],[72,53]
# 3. [49,71],[55,92],[38,82],[53,72]
# 4. [49,55,71,92],[38,72,53,82]
# 5. [38,49,53,55,71,72,82,92]

# %% [markdown]
# 12.18 다음의 정수 배열을 퀵 정렬을 사용하여 오름차순으로 정렬하려고 한다. 각 단계에서의 배열의 내용을 나타내어라. 단, 배열의 첫 번째 요소를 피벗으로 선택한다.
# - [71,49,92,55,38,82,72,53]
#
# 1. [49,55,38,53,71,92,82,72]
# 2. [38,49,55,53,71,92,82,72]
# 3. [38,49,55,53,71,82,72,92]
# 4. [38,49,53,55,71,72,82,92]

# %% [markdown]
# ~12.19 다음의 정수 배열을 퀵 정렬을 사용하여 오름차순으로 정렬하려고 한다. 왼쪽, 중간, 오른쪽 가운데 중간값 (median of three)을 피벗으로 사용하는 경우 정렬의 각 단계에서의 배열의 내용을 적어라.~ 할필요없음
